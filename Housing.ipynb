# %%
import pandas as pd

# %%
housing_df=pd.read_csv("E:/desktop/learning/py/melbourne-housing-market/Melbourne_housing_FULL.csv")

# %%
housing_df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode      ...       Bathroom  Car  Landsize  \
# 0  3/09/2016       2.5    3067.0      ...            1.0  1.0     126.0
# 1  3/12/2016       2.5    3067.0      ...            1.0  1.0     202.0
# 2  4/02/2016       2.5    3067.0      ...            1.0  0.0     156.0
# 3  4/02/2016       2.5    3067.0      ...            2.0  1.0       0.0
# 4  4/03/2017       2.5    3067.0      ...            2.0  0.0     134.0
#
#    BuildingArea  YearBuilt         CouncilArea Lattitude  Longtitude  \
# ...

# %%
housing_df.tail()
# Out:
#            Suburb           Address  Rooms Type      Price Method  \
# 34852  Yarraville       13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville     29A Murray St      2    h   888000.0     SP
# 34854  Yarraville    147A Severn St      2    t   705000.0      S
# 34855  Yarraville  12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville  3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode      ...       Bathroom  \
# 34852            Jas  24/02/2018       6.3    3013.0      ...            1.0
# 34853        Sweeney  24/02/2018       6.3    3013.0      ...            2.0
# 34854            Jas  24/02/2018       6.3    3013.0      ...            1.0
# 34855  hockingstuart  24/02/2018       6.3    3013.0      ...            NaN
# 34856             RW  24/02/2018       6.3    3013.0      ...            1.0
#
#        Car  Landsize  BuildingArea  YearBuilt               CouncilArea  \
# ...

# %%
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
# Suburb           34857 non-null object
# Address          34857 non-null object
# Rooms            34857 non-null int64
# Type             34857 non-null object
# Price            27247 non-null float64
# Method           34857 non-null object
# SellerG          34857 non-null object
# Date             34857 non-null object
# Distance         34856 non-null float64
# Postcode         34856 non-null float64
# Bedroom2         26640 non-null float64
# Bathroom         26631 non-null float64
# Car              26129 non-null float64
# Landsize         23047 non-null float64
# BuildingArea     13742 non-null float64
# YearBuilt        15551 non-null float64
# CouncilArea      34854 non-null object
# Lattitude        26881 non-null float64
# Longtitude       26881 non-null float64
# Regionname       34854 non-null object
# Propertycount    34854 non-null float64
# ...

# %%
housing_df.shape
# Out:
# (34857, 21)

# %%
housing_df.ndim
# Out:
# 2

# %%
housing_df.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
#As we can see below number of columns having numerical attributes is 13 =float64(12), int64(1)  
#and categorical is 8 = object(8)

# %%
housing_df['Price'].describe()
# Out:
# count    2.724700e+04
# mean     1.050173e+06
# std      6.414671e+05
# min      8.500000e+04
# 25%      6.350000e+05
# 50%      8.700000e+05
# 75%      1.295000e+06
# max      1.120000e+07
# Name: Price, dtype: float64

# %%
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
# Suburb           34857 non-null object
# Address          34857 non-null object
# Rooms            34857 non-null int64
# Type             34857 non-null object
# Price            27247 non-null float64
# Method           34857 non-null object
# SellerG          34857 non-null object
# Date             34857 non-null object
# Distance         34856 non-null float64
# Postcode         34856 non-null float64
# Bedroom2         26640 non-null float64
# Bathroom         26631 non-null float64
# Car              26129 non-null float64
# Landsize         23047 non-null float64
# BuildingArea     13742 non-null float64
# YearBuilt        15551 non-null float64
# CouncilArea      34854 non-null object
# Lattitude        26881 non-null float64
# Longtitude       26881 non-null float64
# Regionname       34854 non-null object
# Propertycount    34854 non-null float64
# ...

# %%
housing_df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# ...

# %%
housing_df.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
dupes=housing_df.duplicated()

# %%
sum(dupes)
# Out:
# 1

# %%
#One duplicate data found. Will drop it
dupes=housing_df.duplicated()
housing_df_uniq=housing_df.drop_duplicates()

# %%
housing_df_uniq
# Out:
#                    Suburb              Address  Rooms Type      Price Method  \
# 0              Abbotsford        68 Studley St      2    h        NaN     SS
# 1              Abbotsford         85 Turner St      2    h  1480000.0      S
# 2              Abbotsford      25 Bloomburg St      2    h  1035000.0      S
# 3              Abbotsford   18/659 Victoria St      3    u        NaN     VB
# 4              Abbotsford         5 Charles St      3    h  1465000.0     SP
# 5              Abbotsford     40 Federation La      3    h   850000.0     PI
# 6              Abbotsford          55a Park St      4    h  1600000.0     VB
# 7              Abbotsford         16 Maugie St      4    h        NaN     SN
# 8              Abbotsford         53 Turner St      2    h        NaN      S
# 9              Abbotsford         99 Turner St      2    h        NaN      S
# 10             Abbotsford       129 Charles St      2    h   941000.0      S
# ...

# %%
housing_df_uniq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34856 entries, 0 to 34856
# Data columns (total 21 columns):
# Suburb           34856 non-null object
# Address          34856 non-null object
# Rooms            34856 non-null int64
# Type             34856 non-null object
# Price            27247 non-null float64
# Method           34856 non-null object
# SellerG          34856 non-null object
# Date             34856 non-null object
# Distance         34855 non-null float64
# Postcode         34855 non-null float64
# Bedroom2         26639 non-null float64
# Bathroom         26630 non-null float64
# Car              26128 non-null float64
# Landsize         23046 non-null float64
# BuildingArea     13741 non-null float64
# YearBuilt        15550 non-null float64
# CouncilArea      34853 non-null object
# Lattitude        26880 non-null float64
# Longtitude       26880 non-null float64
# Regionname       34853 non-null object
# Propertycount    34853 non-null float64
# ...

# %%
#We can see 1 table has dropped.

len(housing_df)
# Out:
# 34857

# %%
print("Raw housing_df_uniqdataframe length",len(housing_df))
# Out:
# Raw housing_df_uniqdataframe length 34857

# %%
print("Post Duplicate removal dataframe length",len(housing_df_uniq))
# Out:
# Post Duplicate removal dataframe length 34856

# %%
housing_df_uniq.Bathroom.value_counts()
# Out:
# 1.0     12969
# 2.0     11064
# 3.0      2180
# 4.0       269
# 5.0        77
# 0.0        46
# 6.0        16
# 7.0         4
# 8.0         3
# 9.0         1
# 12.0        1
# Name: Bathroom, dtype: int64

# %%
housing_df_uniq.Bathroom.describe()
# Out:
# count    26630.000000
# mean         1.624747
# std          0.724177
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max         12.000000
# Name: Bathroom, dtype: float64

# %%
housing_df_uniq.Bathroom.fillna(1)

#Bathroom values have been imputed as 1 as it is the most occuring value
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        2.0
# 4        2.0
# 5        2.0
# 6        1.0
# 7        2.0
# 8        1.0
# 9        2.0
# 10       1.0
# 11       2.0
# 12       2.0
# 13       2.0
# 14       1.0
# 15       1.0
# 16       1.0
# 17       1.0
# 18       1.0
# 19       1.0
# 20       1.0
# 21       1.0
# 22       1.0
# 23       2.0
# 24       2.0
# 25       2.0
# 26       1.0
# 27       1.0
# 28       1.0
# 29       1.0
#         ...
# 34827    1.0
# 34828    1.0
# 34829    1.0
# 34830    2.0
# 34831    2.0
# 34832    1.0
# 34833    2.0
# 34834    2.0
# 34835    2.0
# 34836    2.0
# 34837    3.0
# 34838    1.0
# 34839    1.0
# 34840    1.0
# 34841    2.0
# 34842    2.0
# 34843    1.0
# 34844    1.0
# 34845    3.0
# 34846    2.0
# 34847    2.0
# 34848    2.0
# 34849    2.0
# 34850    2.0
# 34851    1.0
# 34852    1.0
# 34853    2.0
# 34854    1.0
# 34855    1.0
# 34856    1.0
# Name: Bathroom, Length: 34856, dtype: float64

# %%
housing_df_uniq.Bathroom.value_counts()
# Out:
# 1.0     12969
# 2.0     11064
# 3.0      2180
# 4.0       269
# 5.0        77
# 0.0        46
# 6.0        16
# 7.0         4
# 8.0         3
# 9.0         1
# 12.0        1
# Name: Bathroom, dtype: int64

# %%
housing_df_uniq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34856 entries, 0 to 34856
# Data columns (total 21 columns):
# Suburb           34856 non-null object
# Address          34856 non-null object
# Rooms            34856 non-null int64
# Type             34856 non-null object
# Price            27247 non-null float64
# Method           34856 non-null object
# SellerG          34856 non-null object
# Date             34856 non-null object
# Distance         34855 non-null float64
# Postcode         34855 non-null float64
# Bedroom2         26639 non-null float64
# Bathroom         26630 non-null float64
# Car              26128 non-null float64
# Landsize         23046 non-null float64
# BuildingArea     13741 non-null float64
# YearBuilt        15550 non-null float64
# CouncilArea      34853 non-null object
# Lattitude        26880 non-null float64
# Longtitude       26880 non-null float64
# Regionname       34853 non-null object
# Propertycount    34853 non-null float64
# ...

# %%
housing_df_uniq.Bathroom.value_counts()
# Out:
# 1.0     12969
# 2.0     11064
# 3.0      2180
# 4.0       269
# 5.0        77
# 0.0        46
# 6.0        16
# 7.0         4
# 8.0         3
# 9.0         1
# 12.0        1
# Name: Bathroom, dtype: int64

# %%
housing_df_uniq.Bathroom.fillna(2,inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:4355: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
housing_df_uniq.Bathroom.value_counts()
# Out:
# 2.0     19290
# 1.0     12969
# 3.0      2180
# 4.0       269
# 5.0        77
# 0.0        46
# 6.0        16
# 7.0         4
# 8.0         3
# 9.0         1
# 12.0        1
# Name: Bathroom, dtype: int64

# %%
housing_df_uniq.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7609
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom             0
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
housing_df_uniq.Bedroom2.fillna(2,inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:4355: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
housing_df_uniq.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7609
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2             0
# Bathroom             0
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
housing_df_uniq['Price'].describe()
# Out:
# count    2.724700e+04
# mean     1.050173e+06
# std      6.414671e+05
# min      8.500000e+04
# 25%      6.350000e+05
# 50%      8.700000e+05
# 75%      1.295000e+06
# max      1.120000e+07
# Name: Price, dtype: float64

# %%
housing_df_uniq['Price'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0              NaN
# 1        1480000.0
# 2        1035000.0
# 3              NaN
# 4        1465000.0
# 5         850000.0
# 6        1600000.0
# 7              NaN
# 8              NaN
# 9              NaN
# 10        941000.0
# 11       1876000.0
# 12             NaN
# 13             NaN
# 14       1636000.0
# 15       1000000.0
# 16        745000.0
# 17        300000.0
# 18       1097000.0
# 19        542000.0
# 20             NaN
# 21        760000.0
# 22        481000.0
# 23        700000.0
# 24       1350000.0
# 25        750000.0
# 26       1985000.0
# 27        500000.0
# 28       1172500.0
# 29        441000.0
#            ...
# 34827    1096000.0
# 34828     900000.0
# 34829          NaN
# 34830    1150000.0
# 34831     675000.0
# 34832     689000.0
# 34833     936000.0
# 34834          NaN
# 34835          NaN
# 34836    1400000.0
# 34837    2020000.0
# 34838     450000.0
# 34839     475000.0
# 34840     520000.0
# ...

# %%
housing_df_uniq.Price.describe()
# Out:
# count    2.724700e+04
# mean     1.050173e+06
# std      6.414671e+05
# min      8.500000e+04
# 25%      6.350000e+05
# 50%      8.700000e+05
# 75%      1.295000e+06
# max      1.120000e+07
# Name: Price, dtype: float64

# %%
#Outliear treatment
import seaborn as sns
sns.boxplot(housing_df_uniq['Price'])

# %%
sns.boxplot(housing_df_uniq['Bathroom'])

# %%
sns.boxplot(housing_df_uniq['Bedroom2'])

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(housing_df_uniq['Price'], housing_df_uniq['Car'])
ax.set_xlabel('Pricing of Houses')
ax.set_ylabel('Cars owned for that house')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-522cb992a282> in <module>()
# ----> 1 fig, ax = plt.subplots(figsize=(16,8))
#       2 ax.scatter(housing_df_uniq['Price'], housing_df_uniq['Car'])
#       3 ax.set_xlabel('Pricing of Houses')
#       4 ax.set_ylabel('Cars owned for that house')
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
# library & dataset
import seaborn as sns

# use the function regplot to make a scatterplot
sns.regplot(x=housing_df_uniq["YearBuilt"], y=housing_df_uniq["Price"],fit_reg=False)
sns.plt.show()
 
# Without regression fit:
sns.regplot(x=df["sepal_length"], y=df["sepal_width"], fit_reg=False)
#sns.plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-e021b49d8ce4> in <module>()
#       4 # use the function regplot to make a scatterplot
#       5 sns.regplot(x=housing_df_uniq["YearBuilt"], y=housing_df_uniq["Price"],fit_reg=False)
# ----> 6 sns.plt.show()
#       7
#       8 # Without regression fit:
#
# AttributeError: module 'seaborn' has no attribute 'plt'

# %%
Q1 = housing_df_uniq.quantile(0.25)
Q3 = housing_df_uniq.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Rooms                 2.000000
# Price            660000.000000
# Distance              7.600000
# Postcode            105.000000
# Bedroom2              1.000000
# Bathroom              1.000000
# Car                   1.000000
# Landsize            446.000000
# BuildingArea         86.000000
# YearBuilt            60.000000
# Lattitude             0.108857
# Longtitude            0.138400
# Propertycount      6027.000000
# dtype: float64

# %%
housing_df_uniq.Car.value_counts()
# Out:
# 2.0     12213
# 1.0      9164
# 0.0      1631
# 3.0      1606
# 4.0      1161
# 5.0       151
# 6.0       140
# 7.0        25
# 8.0        23
# 10.0        6
# 9.0         3
# 11.0        2
# 26.0        1
# 12.0        1
# 18.0        1
# Name: Car, dtype: int64

# %%
housing_df_uniq.Car.describe()
# Out:
# count    26128.000000
# mean         1.728835
# std          1.010789
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max         26.000000
# Name: Car, dtype: float64

# %%
housing_df_uniq.Car.fillna(1.728835)
# Out:
# 0        1.000000
# 1        1.000000
# 2        0.000000
# 3        1.000000
# 4        0.000000
# 5        1.000000
# 6        2.000000
# 7        2.000000
# 8        2.000000
# 9        1.000000
# 10       0.000000
# 11       0.000000
# 12       1.000000
# 13       0.000000
# 14       2.000000
# 15       1.728835
# 16       1.728835
# 17       1.000000
# 18       2.000000
# 19       1.728835
# 20       1.000000
# 21       1.728835
# 22       1.728835
# 23       1.000000
# 24       2.000000
# 25       1.000000
# 26       1.728835
# 27       1.728835
# 28       1.000000
# 29       1.000000
#            ...
# 34827    3.000000
# 34828    2.000000
# 34829    1.728835
# 34830    2.000000
# 34831    5.000000
# 34832    1.728835
# 34833    2.000000
# 34834    2.000000
# 34835    2.000000
# 34836    2.000000
# 34837    2.000000
# 34838    1.728835
# 34839    1.728835
# 34840    1.728835
# 34841    1.000000
# 34842    1.728835
# 34843    2.000000
# 34844    1.728835
# 34845    2.000000
# ...

# %%
housing_df_uniq.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7609
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2             0
# Bathroom             0
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
def trendline(data, order=1):
    coeffs = np.polyfit(data.index.values, list(data), order)
    slope = coeffs[-2]
    return float(slope)

slope = trendline(housing_df_uniq['Price']
print(slope)
# Out:
#   File "<ipython-input-73-1748d2e2a273>", line 8
#     print(slope)
#         ^
# SyntaxError: invalid syntax

# %%
#For applying distance based algorithm we need to standardise Distance column

# %%
#there are certain Outliers as in price but I'd not remove them as they can be telling of the price discrimination rather than wrong data
